# %% [markdown]
# <a href="https://colab.research.google.com/github/Shreeharinadig/ML-AND-DATA-SCIENCE/blob/main/EDAassignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# IMPORTING THE DATASET

# %%
df=pd.read_csv('dataset (1).csv')

# %% [markdown]
# DATA PRE-PROCESSING

# %%
x=df.iloc[:,:-3].values
y=df.iloc[:,-2].values
print(x)
print(y)
# Out:
# [[0.00000000e+00 1.12900002e+02 1.18800003e+02 ... 1.15910004e+02
#   0.00000000e+00 1.28869318e+09]
#  [1.00000000e+00 3.49312997e+00 3.69246006e+00 ... 3.59088993e+00
#   0.00000000e+00 6.22981854e+07]
#  [2.00000000e+00 1.15980003e+02 1.24663002e+02 ... 1.12300003e+02
#   0.00000000e+00 1.24902306e+09]
#  ...
#  [7.29430000e+04 4.95043050e+00 5.14856503e+00 ... 5.11720618e+00
#   1.06949684e+08 1.55955136e+09]
#  [7.29440000e+04 2.32574756e-04 2.42955206e-04 ... 2.39199548e-04
#   2.14326818e+08 1.57629117e+09]
#  [7.29450000e+04 4.65489948e-01 4.71005527e-01 ... 4.69033386e-01
#   9.50974305e+08 2.33986759e+10]]
# ['Bitcoin' 'Litecoin' 'Bitcoin' ... 'Filecoin' 'Terra Classic' 'XRP']

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x1 = sc.fit_transform(x)
print(x1)
# Out:
# [[-1.73202706 -0.14475338 -0.14404029 ... -0.14428209 -0.22953305
#   -0.1794472 ]
#  [-1.73197957 -0.16566601 -0.16536212 ... -0.16573557 -0.22953305
#   -0.19579672]
#  [-1.73193209 -0.14416465 -0.14295426 ... -0.14497161 -0.22953305
#   -0.17997606]
#  ...
#  [ 1.73193209 -0.16538745 -0.1650924  ... -0.16544404 -0.2184131
#   -0.1758363 ]
#  [ 1.73197957 -0.16633366 -0.16604605 ... -0.1664214  -0.2072487
#   -0.17561313]
#  [ 1.73202706 -0.16624473 -0.16595885 ... -0.16633186 -0.13065675
#    0.11530903]]

# %%
df.head(5)
# Out:
#    Unnamed: 0        open        high         low       close  volume  \
# 0           0  112.900002  118.800003  107.142998  115.910004     0.0
# 1           1    3.493130    3.692460    3.346060    3.590890     0.0
# 2           2  115.980003  124.663002  106.639999  112.300003     0.0
# 3           3    3.594220    3.781020    3.116020    3.371250     0.0
# 4           4  112.250000  113.444000   97.699997  111.500000     0.0
#
#       marketCap                 timestamp crypto_name        date
# 0  1.288693e+09  2013-05-05T23:59:59.999Z     Bitcoin  2013-05-05
# 1  6.229819e+07  2013-05-05T23:59:59.999Z    Litecoin  2013-05-05
# 2  1.249023e+09  2013-05-06T23:59:59.999Z     Bitcoin  2013-05-06
# 3  5.859436e+07  2013-05-06T23:59:59.999Z    Litecoin  2013-05-06
# 4  1.240594e+09  2013-05-07T23:59:59.999Z     Bitcoin  2013-05-07

# %%
df.describe()
# Out:
#          Unnamed: 0          open          high           low         close  \
# count  72946.000000  72946.000000  7.294600e+04  72946.000000  7.294600e+04
# mean   36472.500000    870.194495  8.964124e+02    844.060640  8.712949e+02
# std    21057.840705   5231.654470  5.398613e+03   5079.389387  5.235508e+03
# min        0.000000      0.000000  1.022100e-10      0.000000  8.292000e-11
# 25%    18236.250000      0.167916  1.767999e-01      0.158630  1.682982e-01
# 50%    36472.500000      1.630666  1.717542e+00      1.541486  1.640219e+00
# 75%    54708.750000     26.070557  2.756868e+01     24.791776  2.625195e+01
# max    72945.000000  67549.735581  1.621883e+05  66458.723733  6.756683e+04
#
#              volume     marketCap
# count  7.294600e+04  7.294600e+04
# mean   2.207607e+09  1.474922e+10
# std    9.617885e+09  7.501159e+10
# min    0.000000e+00  0.000000e+00
# 25%    8.320618e+06  1.860432e+08
# 50%    1.098756e+08  1.268539e+09
# 75%    6.691398e+08  5.118618e+09
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0     0
# open           0
# high           0
# low            0
# close          0
# volume         0
# marketCap      0
# timestamp      0
# crypto_name    0
# date           0
# dtype: int64

# %% [markdown]
# DATA VISUALISATION

# %%
df.plot(legend=True,subplots=True, figsize = (12, 6))
plt.show()

# %%
df['close'].groupby(df['crypto_name'].head(5000)).plot(legend=True, figsize = (12, 6))
plt.show()

# %%
df['marketCap'].groupby(df['crypto_name'].head(5000)).plot(legend=True, figsize = (12, 6))
plt.show()

# %%
df['volume'].groupby(df['crypto_name'].head(5000)).plot(legend=True,figsize=(12,7))
plt.show()

# %%
print(set(y))
# Out:
# {'Cosmos', 'Decentraland', 'Uniswap', 'USD Coin', 'Cronos', 'Solana', 'Bitcoin', 'Elrond', 'Internet Computer', 'ApeCoin', 'BNB', 'Litecoin', 'Tezos', 'Filecoin', 'VeChain', 'Shiba Inu', 'TRON', 'Theta Network', 'Polkadot', 'Tether', 'XRP', 'Quant', 'Chain', 'FTX Token', 'Dogecoin', 'Casper', 'Stellar', 'Maker', 'Avalanche', 'Ravencoin', 'Cardano', 'Ethereum Classic', 'Monero', 'UNUS SED LEO', 'Polygon', 'Terra Classic', 'Toncoin', 'Chainlink', 'Ethereum', 'Aave', 'Aptos', 'Chiliz', 'Binance USD', 'Wrapped Bitcoin', 'THORChain', 'Basic Attention Token', 'The Sandbox', 'Huobi Token', 'NEAR Protocol', 'Flow', 'OKB', 'EOS', 'Hedera', 'Algorand', 'Dai', 'Bitcoin Cash'}
